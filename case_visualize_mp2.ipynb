# %% [markdown]
# this script is for visualizing the results from the case study

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from scipy import stats
import numpy as np
import pandas as pd
import matplotlib.patches as mpatches

# %%
from src.game_theory_helpers import powerset, is_convex_game, get_loo, get_shapley_value, get_nash_bargaining_solution, get_banzhaf_value, core_nonempty, game_is_superadditive, make_game_superadditive
from src.nucleolus import get_nucleolus
from src.least_core_nucleolus import get_least_core_nucleolus

# %%
# Get the Tab20 colormap
cmap = plt.cm.get_cmap("tab20")

# Extract the first 4 colors
base_colors = [cmap(i) for i in range(10)]

# Create extended cycle: first full alpha, then alpha=0.5
colors = base_colors + [(r, g, b, 0.5) for (r, g, b, _) in base_colors]

# Set this as default color cycle
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=colors)
plt.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    # "font.serif": ["Computer Modern Roman"],
    "mathtext.fontset": "cm", # 'cm' stands for Computer Modern
    "font.size": 15,  # plt.rcParams.update({'font.size': 15})
})
# Out:
# C:\Users\carlv\AppData\Local\Temp\ipykernel_32452\940924037.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab20")

# %% [markdown]
# # Set Parameters

# %%
# PARAMS
MAKE_games_superadditive = True   # use superadditive formulation
MAKE_REALIZED_SUPERADDITIVE = False
devices = ['PV', 'Wind', 'BESS']
GAME_types_to_plot = ['Shapley']  # ['Shapley', 'Nucleolus', 'Sub-Game']
# main_path = 'pics/v_TESTING/'
# main_path = 'pics/mp_mid_k/'
main_path = 'pics/mp_optimal_spring/'
# main_path = 'pics/mp_ilmar_spring/'
services = ['FFR + FCR-D']  # list of services to visualize

# %%
dvpps_infos = {}  # dictionary to hold dvpp info dataframes
df_expected = pd.DataFrame()
df_realized = pd.DataFrame()
dvpp_info = pd.DataFrame()
df_bids = pd.DataFrame()

df_expected = pd.read_csv(f'{main_path}expected_values_DPF.csv', index_col=[0,1], header=[0,1,2])
df_expected.columns = [tuple(c for c in col if c!='nan') for col in df_expected.columns.values]
df_realized = pd.read_csv(f'{main_path}values_DPF.csv', index_col=[0,1], header=[0,1,2])
df_realized.columns = [tuple(c for c in col if c!='nan') for col in df_realized.columns.values]
for service in services:
    dvpps_infos[service] = pd.read_csv(f'{main_path}dvpp_info_DPF_{service}.csv', index_col=[0,1], parse_dates=True, date_format='%Y-%m-%d %H:%M:%S')

# %% [markdown]
# ## Pure-Nucleolus Reward Split

# %%
# get reward split of devices
players = [c[0] for c in df_expected.columns if len(c)==1]
idxes = pd.MultiIndex.from_product((df_expected.index.get_level_values(1), ['E-Value', 'E-Nucleolus', 'R-Value', 'R-Nucleolus']))
df_reward_split = pd.DataFrame(0.0, index=idxes, columns=players)
superadditivity_counter = 0
convexity_counter = 0
core_non_empty_counter = 0
for idx, row in df_expected.iterrows():
    # 1. Expected game convert to dictionary
    v = {frozenset(k): val for k, val in row.items()}
    v[frozenset()] = 0.0  # ensure empty set has value 0
    # v = make_game_superadditive(v, players)  # ensure superadditivity
    if game_is_superadditive(v, players):
        superadditivity_counter += 1
        nucleolus = get_nucleolus(v, players)
    else:
        print(f"for time {idx[0]}, expected game is not superadditive.")
        print(v)
        nucleolus = get_least_core_nucleolus(v, players)
    if is_convex_game(v, players):
        convexity_counter += 1
    if core_nonempty(v, players):
        core_non_empty_counter += 1
    df_reward_split.loc[(idx[1], 'E-Nucleolus'), list(k for k in nucleolus.keys())] = list(nucleolus.values())
    df_reward_split.loc[(idx[1], 'E-Value'), list(p for p in players)] = [v[frozenset({p})] for p in players]
    # 2. Realized game convert to dictionary
    v_realized = {frozenset(k): val for k, val in df_realized.loc[idx].items()}
    v_realized[frozenset()] = 0.0  # ensure empty set
    nucleolus_realized = get_least_core_nucleolus(v_realized, players)
    df_reward_split.loc[(idx[1], 'R-Nucleolus'), list(k for k in nucleolus_realized.keys())] = list(nucleolus_realized.values())
    df_reward_split.loc[(idx[1], 'R-Value'), list(p for p in players)] = [v_realized[frozenset({p})] for p in players]
# Out:
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.0, frozenset({'Wind'}): 0.12906, frozenset({'BESS'}): 13.10625, frozenset({'PV', 'Wind'}): 0.23231, frozenset({'BESS', 'PV'}): 13.10625, frozenset({'BESS', 'Wind'}): 13.10625, frozenset({'BESS', 'PV', 'Wind'}): 13.10625, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.0, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 13.10625, frozenset({'PV', 'Wind'}): 0.01566, frozenset({'BESS', 'PV'}): 13.10625, frozenset({'BESS', 'Wind'}): 13.10625, frozenset({'BESS', 'PV', 'Wind'}): 13.10625, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.22759, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 1.21875, frozenset({'PV', 'Wind'}): 0.14928, frozenset({'BESS', 'PV'}): 1.41583, frozenset({'BESS', 'Wind'}): 1.21875, frozenset({'BESS', 'PV', 'Wind'}): 1.41583, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 1.94206, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 4.03125, frozenset({'PV', 'Wind'}): 1.50096, frozenset({'BESS', 'PV'}): 6.20651, frozenset({'BESS', 'Wind'}): 4.03125, frozenset({'BESS', 'PV', 'Wind'}): 6.59432, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 20.03012, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 17.79375, frozenset({'PV', 'Wind'}): 13.14545, frozenset({'BESS', 'PV'}): 40.2291, frozenset({'BESS', 'Wind'}): 17.79375, frozenset({'BESS', 'PV', 'Wind'}): 40.24213, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 22.81612, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 21.7875, frozenset({'PV', 'Wind'}): 19.132, frozenset({'BESS', 'PV'}): 47.3434, frozenset({'BESS', 'Wind'}): 21.7875, frozenset({'BESS', 'PV', 'Wind'}): 53.10981, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 188.97008, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 95.34375, frozenset({'PV', 'Wind'}): 130.78226, frozenset({'BESS', 'PV'}): 307.00549, frozenset({'BESS', 'Wind'}): 95.34375, frozenset({'BESS', 'PV', 'Wind'}): 318.6796, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 227.78685, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 95.34375, frozenset({'PV', 'Wind'}): 149.40611, frozenset({'BESS', 'PV'}): 350.48341, frozenset({'BESS', 'Wind'}): 95.34375, frozenset({'BESS', 'PV', 'Wind'}): 350.48341, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 196.46166, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 95.4375, frozenset({'PV', 'Wind'}): 129.12461, frozenset({'BESS', 'PV'}): 315.49042, frozenset({'BESS', 'Wind'}): 95.4375, frozenset({'BESS', 'PV', 'Wind'}): 315.9426, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 216.6808, frozenset({'Wind'}): 7.40574, frozenset({'BESS'}): 94.725, frozenset({'PV', 'Wind'}): 147.8744, frozenset({'BESS', 'PV'}): 337.42498, frozenset({'BESS', 'Wind'}): 94.725, frozenset({'BESS', 'PV', 'Wind'}): 347.24898, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 212.47442, frozenset({'Wind'}): 8.96901, frozenset({'BESS'}): 94.425, frozenset({'PV', 'Wind'}): 142.22152, frozenset({'BESS', 'PV'}): 332.4135, frozenset({'BESS', 'Wind'}): 94.425, frozenset({'BESS', 'PV', 'Wind'}): 337.2956, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 86.86421, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 94.425, frozenset({'PV', 'Wind'}): 59.60259, frozenset({'BESS', 'PV'}): 191.71993, frozenset({'BESS', 'Wind'}): 94.425, frozenset({'BESS', 'PV', 'Wind'}): 196.20789, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 65.50878, frozenset({'Wind'}): 9.55937, frozenset({'BESS'}): 94.8375, frozenset({'PV', 'Wind'}): 42.96741, frozenset({'BESS', 'PV'}): 168.21262, frozenset({'BESS', 'Wind'}): 94.8375, frozenset({'BESS', 'PV', 'Wind'}): 168.21262, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.60734, frozenset({'Wind'}): 0.73956, frozenset({'BESS'}): 3.0375, frozenset({'PV', 'Wind'}): 1.19062, frozenset({'BESS', 'PV'}): 3.71778, frozenset({'BESS', 'Wind'}): 3.51481, frozenset({'BESS', 'PV', 'Wind'}): 4.71551, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.32776, frozenset({'Wind'}): 0.33608, frozenset({'BESS'}): 3.75, frozenset({'PV', 'Wind'}): 0.78047, frozenset({'BESS', 'PV'}): 3.97314, frozenset({'BESS', 'Wind'}): 3.75, frozenset({'BESS', 'PV', 'Wind'}): 4.37335, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.0, frozenset({'Wind'}): 0.33487, frozenset({'BESS'}): 16.85625, frozenset({'PV', 'Wind'}): 0.41534, frozenset({'BESS', 'PV'}): 16.85625, frozenset({'BESS', 'Wind'}): 16.85625, frozenset({'BESS', 'PV', 'Wind'}): 16.97559, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.0, frozenset({'Wind'}): 0.62237, frozenset({'BESS'}): 4.6875, frozenset({'PV', 'Wind'}): 0.62591, frozenset({'BESS', 'PV'}): 4.6875, frozenset({'BESS', 'Wind'}): 4.91963, frozenset({'BESS', 'PV', 'Wind'}): 4.91963, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.03953, frozenset({'Wind'}): 0.04194, frozenset({'BESS'}): 2.8125, frozenset({'PV', 'Wind'}): 0.20614, frozenset({'BESS', 'PV'}): 2.8125, frozenset({'BESS', 'Wind'}): 2.8125, frozenset({'BESS', 'PV', 'Wind'}): 3.16452, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.13044, frozenset({'Wind'}): 0.05059, frozenset({'BESS'}): 1.875, frozenset({'PV', 'Wind'}): 0.1627, frozenset({'BESS', 'PV'}): 2.02038, frozenset({'BESS', 'Wind'}): 1.875, frozenset({'BESS', 'PV', 'Wind'}): 2.1335, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.02319, frozenset({'Wind'}): 0.23094, frozenset({'BESS'}): 1.875, frozenset({'PV', 'Wind'}): 0.26522, frozenset({'BESS', 'PV'}): 1.875, frozenset({'BESS', 'Wind'}): 1.875, frozenset({'BESS', 'PV', 'Wind'}): 1.97337, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 2.20237, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 2.8125, frozenset({'PV', 'Wind'}): 1.52014, frozenset({'BESS', 'PV'}): 5.27933, frozenset({'BESS', 'Wind'}): 2.8125, frozenset({'BESS', 'PV', 'Wind'}): 5.40843, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 4.91232, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 3.75, frozenset({'PV', 'Wind'}): 3.22201, frozenset({'BESS', 'PV'}): 9.2522, frozenset({'BESS', 'Wind'}): 3.75, frozenset({'BESS', 'PV', 'Wind'}): 9.2522, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 4.27534, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 2.8125, frozenset({'PV', 'Wind'}): 2.86011, frozenset({'BESS', 'PV'}): 7.60123, frozenset({'BESS', 'Wind'}): 2.8125, frozenset({'BESS', 'PV', 'Wind'}): 7.6817, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 15.16334, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 7.48125, frozenset({'PV', 'Wind'}): 10.31152, frozenset({'BESS', 'PV'}): 24.46542, frozenset({'BESS', 'Wind'}): 7.48125, frozenset({'BESS', 'PV', 'Wind'}): 25.09015, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 75.38036, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 30.0, frozenset({'PV', 'Wind'}): 50.87243, frozenset({'BESS', 'PV'}): 114.43209, frozenset({'BESS', 'Wind'}): 30.0, frozenset({'BESS', 'PV', 'Wind'}): 116.87446, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 232.29685, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 96.2625, frozenset({'PV', 'Wind'}): 152.36423, frozenset({'BESS', 'PV'}): 356.45372, frozenset({'BESS', 'Wind'}): 96.2625, frozenset({'BESS', 'PV', 'Wind'}): 356.45372, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 226.23857, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 96.2625, frozenset({'PV', 'Wind'}): 152.75975, frozenset({'BESS', 'PV'}): 349.66796, frozenset({'BESS', 'Wind'}): 96.2625, frozenset({'BESS', 'PV', 'Wind'}): 357.12916, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 183.9308, frozenset({'Wind'}): 3.39017, frozenset({'BESS'}): 96.2625, frozenset({'PV', 'Wind'}): 126.52297, frozenset({'BESS', 'PV'}): 302.27984, frozenset({'BESS', 'Wind'}): 96.2625, frozenset({'BESS', 'PV', 'Wind'}): 312.32481, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 156.78891, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 95.325, frozenset({'PV', 'Wind'}): 102.83833, frozenset({'BESS', 'PV'}): 270.94123, frozenset({'BESS', 'Wind'}): 95.325, frozenset({'BESS', 'PV', 'Wind'}): 270.94123, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 3.81999, frozenset({'Wind'}): 0.08019, frozenset({'BESS'}): 2.8125, frozenset({'PV', 'Wind'}): 2.51833, frozenset({'BESS', 'PV'}): 7.0912, frozenset({'BESS', 'Wind'}): 2.8125, frozenset({'BESS', 'PV', 'Wind'}): 7.11304, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 2.36994, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 3.0375, frozenset({'PV', 'Wind'}): 1.56453, frozenset({'BESS', 'PV'}): 5.69202, frozenset({'BESS', 'Wind'}): 3.0375, frozenset({'BESS', 'PV', 'Wind'}): 5.69202, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.45625, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 4.66875, frozenset({'PV', 'Wind'}): 0.59123, frozenset({'BESS', 'PV'}): 4.93425, frozenset({'BESS', 'Wind'}): 4.66875, frozenset({'BESS', 'PV', 'Wind'}): 4.93425, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.0, frozenset({'Wind'}): 0.50481, frozenset({'BESS'}): 4.6875, frozenset({'PV', 'Wind'}): 0.52079, frozenset({'BESS', 'PV'}): 4.6875, frozenset({'BESS', 'Wind'}): 4.6875, frozenset({'BESS', 'PV', 'Wind'}): 4.6875, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.0, frozenset({'Wind'}): 0.09759, frozenset({'BESS'}): 4.6875, frozenset({'PV', 'Wind'}): 0.09759, frozenset({'BESS', 'PV'}): 4.6875, frozenset({'BESS', 'Wind'}): 4.6875, frozenset({'BESS', 'PV', 'Wind'}): 4.6875, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.49751, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 1.875, frozenset({'PV', 'Wind'}): 0.33359, frozenset({'BESS', 'PV'}): 2.06441, frozenset({'BESS', 'Wind'}): 1.875, frozenset({'BESS', 'PV', 'Wind'}): 2.3375, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 1.57067, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 4.6875, frozenset({'PV', 'Wind'}): 1.27261, frozenset({'BESS', 'PV'}): 6.07968, frozenset({'BESS', 'Wind'}): 4.6875, frozenset({'BESS', 'PV', 'Wind'}): 6.47808, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 4.74849, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 7.5, frozenset({'PV', 'Wind'}): 3.11455, frozenset({'BESS', 'PV'}): 12.8187, frozenset({'BESS', 'Wind'}): 7.5, frozenset({'BESS', 'PV', 'Wind'}): 12.8187, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 13.19938, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 9.375, frozenset({'PV', 'Wind'}): 9.38599, frozenset({'BESS', 'PV'}): 24.15937, frozenset({'BESS', 'Wind'}): 9.375, frozenset({'BESS', 'PV', 'Wind'}): 25.32974, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 7.00279, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 4.6875, frozenset({'PV', 'Wind'}): 4.59315, frozenset({'BESS', 'PV'}): 12.53119, frozenset({'BESS', 'Wind'}): 4.6875, frozenset({'BESS', 'PV', 'Wind'}): 12.53119, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 34.36527, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 23.4375, frozenset({'PV', 'Wind'}): 22.54029, frozenset({'BESS', 'PV'}): 61.92937, frozenset({'BESS', 'Wind'}): 23.4375, frozenset({'BESS', 'PV', 'Wind'}): 61.92937, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 33.78217, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 22.5, frozenset({'PV', 'Wind'}): 22.63772, frozenset({'BESS', 'PV'}): 60.33876, frozenset({'BESS', 'Wind'}): 22.5, frozenset({'BESS', 'PV', 'Wind'}): 61.0249, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 21.14788, frozenset({'Wind'}): 0.06707, frozenset({'BESS'}): 22.5, frozenset({'PV', 'Wind'}): 15.32408, frozenset({'BESS', 'PV'}): 46.18733, frozenset({'BESS', 'Wind'}): 22.5, frozenset({'BESS', 'PV', 'Wind'}): 48.58854, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 26.96643, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 22.5, frozenset({'PV', 'Wind'}): 18.17265, frozenset({'BESS', 'PV'}): 52.70458, frozenset({'BESS', 'Wind'}): 22.5, frozenset({'BESS', 'PV', 'Wind'}): 53.39072, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 6.6835, frozenset({'Wind'}): 0.01208, frozenset({'BESS'}): 3.75, frozenset({'PV', 'Wind'}): 4.45138, frozenset({'BESS', 'PV'}): 11.23605, frozenset({'BESS', 'Wind'}): 3.75, frozenset({'BESS', 'PV', 'Wind'}): 11.35159, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 2.68209, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 1.875, frozenset({'PV', 'Wind'}): 1.82895, frozenset({'BESS', 'PV'}): 4.87915, frozenset({'BESS', 'Wind'}): 1.875, frozenset({'BESS', 'PV', 'Wind'}): 4.97918, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 1.66967, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 2.8125, frozenset({'PV', 'Wind'}): 1.09514, frozenset({'BESS', 'PV'}): 4.68267, frozenset({'BESS', 'Wind'}): 2.8125, frozenset({'BESS', 'PV', 'Wind'}): 4.68267, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.38527, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 3.75, frozenset({'PV', 'Wind'}): 0.37586, frozenset({'BESS', 'PV'}): 3.75, frozenset({'BESS', 'Wind'}): 3.75, frozenset({'BESS', 'PV', 'Wind'}): 4.04953, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.0, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 4.6875, frozenset({'PV', 'Wind'}): 0.01373, frozenset({'BESS', 'PV'}): 4.6875, frozenset({'BESS', 'Wind'}): 4.6875, frozenset({'BESS', 'PV', 'Wind'}): 4.6875, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.07042, frozenset({'Wind'}): 3.49742, frozenset({'BESS'}): 1.6875, frozenset({'PV', 'Wind'}): 3.61551, frozenset({'BESS', 'PV'}): 1.6875, frozenset({'BESS', 'Wind'}): 6.48017, frozenset({'BESS', 'PV', 'Wind'}): 6.48017, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.03955, frozenset({'Wind'}): 6.79314, frozenset({'BESS'}): 1.875, frozenset({'PV', 'Wind'}): 6.96379, frozenset({'BESS', 'PV'}): 1.875, frozenset({'BESS', 'Wind'}): 11.27698, frozenset({'BESS', 'PV', 'Wind'}): 11.56147, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.89248, frozenset({'Wind'}): 6.65376, frozenset({'BESS'}): 1.875, frozenset({'PV', 'Wind'}): 7.47431, frozenset({'BESS', 'PV'}): 2.87465, frozenset({'BESS', 'Wind'}): 11.08407, frozenset({'BESS', 'PV', 'Wind'}): 12.44376, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 9.89574, frozenset({'Wind'}): 23.59638, frozenset({'BESS'}): 6.5625, frozenset({'PV', 'Wind'}): 31.48657, frozenset({'BESS', 'PV'}): 17.64653, frozenset({'BESS', 'Wind'}): 39.22084, frozenset({'BESS', 'PV', 'Wind'}): 52.42876, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 43.33902, frozenset({'Wind'}): 77.9172, frozenset({'BESS'}): 22.44375, frozenset({'PV', 'Wind'}): 106.50998, frozenset({'BESS', 'PV'}): 70.98695, frozenset({'BESS', 'Wind'}): 130.28426, frozenset({'BESS', 'PV', 'Wind'}): 178.82745, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 24.90978, frozenset({'Wind'}): 88.58915, frozenset({'BESS'}): 26.25, frozenset({'PV', 'Wind'}): 108.80169, frozenset({'BESS', 'PV'}): 54.15096, frozenset({'BESS', 'Wind'}): 148.86092, frozenset({'BESS', 'PV', 'Wind'}): 183.09399, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 47.71769, frozenset({'Wind'}): 114.72657, frozenset({'BESS'}): 37.4625, frozenset({'PV', 'Wind'}): 149.9225, frozenset({'BESS', 'PV'}): 90.91016, frozenset({'BESS', 'Wind'}): 196.24865, frozenset({'BESS', 'PV', 'Wind'}): 255.56731, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 45.62662, frozenset({'Wind'}): 64.11435, frozenset({'BESS'}): 23.4375, frozenset({'PV', 'Wind'}): 95.38236, frozenset({'BESS', 'PV'}): 74.543, frozenset({'BESS', 'Wind'}): 112.17432, frozenset({'BESS', 'PV', 'Wind'}): 165.36032, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 34.81395, frozenset({'Wind'}): 72.03405, frozenset({'BESS'}): 23.4375, frozenset({'PV', 'Wind'}): 96.3861, frozenset({'BESS', 'PV'}): 62.43194, frozenset({'BESS', 'Wind'}): 123.13549, frozenset({'BESS', 'PV', 'Wind'}): 164.21193, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 10.80196, frozenset({'Wind'}): 28.42126, frozenset({'BESS'}): 9.3375, frozenset({'PV', 'Wind'}): 36.84109, frozenset({'BESS', 'PV'}): 21.43656, frozenset({'BESS', 'Wind'}): 48.67366, frozenset({'BESS', 'PV', 'Wind'}): 63.00365, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 7.43811, frozenset({'Wind'}): 29.99247, frozenset({'BESS'}): 9.3375, frozenset({'PV', 'Wind'}): 37.19236, frozenset({'BESS', 'PV'}): 17.66879, frozenset({'BESS', 'Wind'}): 50.84828, frozenset({'BESS', 'PV', 'Wind'}): 63.09208, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 1.86184, frozenset({'Wind'}): 28.78941, frozenset({'BESS'}): 9.3375, frozenset({'PV', 'Wind'}): 31.24314, frozenset({'BESS', 'PV'}): 10.89504, frozenset({'BESS', 'Wind'}): 48.70595, frozenset({'BESS', 'PV', 'Wind'}): 53.4595, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 1.43393, frozenset({'Wind'}): 1.59639, frozenset({'BESS'}): 3.75, frozenset({'PV', 'Wind'}): 2.98171, frozenset({'BESS', 'PV'}): 4.73037, frozenset({'BESS', 'Wind'}): 5.95947, frozenset({'BESS', 'PV', 'Wind'}): 8.32141, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 4.73463, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 4.6875, frozenset({'PV', 'Wind'}): 3.28836, frozenset({'BESS', 'PV'}): 9.99067, frozenset({'BESS', 'Wind'}): 4.6875, frozenset({'BESS', 'PV', 'Wind'}): 10.2772, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 5.25014, frozenset({'Wind'}): 0.02899, frozenset({'BESS'}): 3.75, frozenset({'PV', 'Wind'}): 3.58844, frozenset({'BESS', 'PV'}): 9.63058, frozenset({'BESS', 'Wind'}): 3.75, frozenset({'BESS', 'PV', 'Wind'}): 9.83117, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 6.95937, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 3.75, frozenset({'PV', 'Wind'}): 5.02141, frozenset({'BESS', 'PV'}): 11.54505, frozenset({'BESS', 'Wind'}): 3.75, frozenset({'BESS', 'PV', 'Wind'}): 12.32503, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 7.23187, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 3.75, frozenset({'PV', 'Wind'}): 4.74341, frozenset({'BESS', 'PV'}): 11.85028, frozenset({'BESS', 'Wind'}): 3.75, frozenset({'BESS', 'PV', 'Wind'}): 11.85028, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 9.6719, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 7.5, frozenset({'PV', 'Wind'}): 6.34383, frozenset({'BESS', 'PV'}): 18.33331, frozenset({'BESS', 'Wind'}): 7.5, frozenset({'BESS', 'PV', 'Wind'}): 18.33331, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 14.56609, frozenset({'Wind'}): 0.37307, frozenset({'BESS'}): 11.2125, frozenset({'PV', 'Wind'}): 10.3601, frozenset({'BESS', 'PV'}): 27.5277, frozenset({'BESS', 'Wind'}): 11.2125, frozenset({'BESS', 'PV', 'Wind'}): 28.90437, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 26.0169, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 23.6625, frozenset({'PV', 'Wind'}): 18.50639, frozenset({'BESS', 'PV'}): 52.80352, frozenset({'BESS', 'Wind'}): 23.6625, frozenset({'BESS', 'PV', 'Wind'}): 55.26572, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 3.86189, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 4.6875, frozenset({'PV', 'Wind'}): 2.53303, frozenset({'BESS', 'PV'}): 9.01313, frozenset({'BESS', 'Wind'}): 4.6875, frozenset({'BESS', 'PV', 'Wind'}): 9.01313, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 1.86718, frozenset({'Wind'}): 0.6481, frozenset({'BESS'}): 3.75, frozenset({'PV', 'Wind'}): 1.76423, frozenset({'BESS', 'PV'}): 5.8414, frozenset({'BESS', 'Wind'}): 3.83145, frozenset({'BESS', 'PV', 'Wind'}): 6.76275, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.88511, frozenset({'Wind'}): 28.15255, frozenset({'BESS'}): 7.5, frozenset({'PV', 'Wind'}): 28.55547, frozenset({'BESS', 'PV'}): 8.01784, frozenset({'BESS', 'Wind'}): 46.46425, frozenset({'BESS', 'PV', 'Wind'}): 47.12071, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.26074, frozenset({'Wind'}): 8.77624, frozenset({'BESS'}): 15.0, frozenset({'PV', 'Wind'}): 9.11335, frozenset({'BESS', 'PV'}): 15.0, frozenset({'BESS', 'Wind'}): 27.14667, frozenset({'BESS', 'PV', 'Wind'}): 27.70831, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.0, frozenset({'Wind'}): 0.85789, frozenset({'BESS'}): 15.0, frozenset({'PV', 'Wind'}): 0.91443, frozenset({'BESS', 'PV'}): 15.0, frozenset({'BESS', 'Wind'}): 15.0, frozenset({'BESS', 'PV', 'Wind'}): 15.0, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.61024, frozenset({'Wind'}): 14.22254, frozenset({'BESS'}): 4.06875, frozenset({'PV', 'Wind'}): 15.32873, frozenset({'BESS', 'PV'}): 4.38269, frozenset({'BESS', 'Wind'}): 23.75331, frozenset({'BESS', 'PV', 'Wind'}): 25.63388, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.22772, frozenset({'Wind'}): 10.2051, frozenset({'BESS'}): 3.0, frozenset({'PV', 'Wind'}): 10.2051, frozenset({'BESS', 'PV'}): 3.0, frozenset({'BESS', 'Wind'}): 17.12426, frozenset({'BESS', 'PV', 'Wind'}): 17.12426, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.40146, frozenset({'Wind'}): 67.5787, frozenset({'BESS'}): 23.25, frozenset({'PV', 'Wind'}): 70.11921, frozenset({'BESS', 'PV'}): 23.25, frozenset({'BESS', 'Wind'}): 116.78162, frozenset({'BESS', 'PV', 'Wind'}): 121.02929, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.0, frozenset({'Wind'}): 3.33323, frozenset({'BESS'}): 51.54375, frozenset({'PV', 'Wind'}): 5.41981, frozenset({'BESS', 'PV'}): 51.54375, frozenset({'BESS', 'Wind'}): 51.54375, frozenset({'BESS', 'PV', 'Wind'}): 51.54375, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.0, frozenset({'Wind'}): 1.86231, frozenset({'BESS'}): 23.25, frozenset({'PV', 'Wind'}): 2.84197, frozenset({'BESS', 'PV'}): 23.25, frozenset({'BESS', 'Wind'}): 23.25, frozenset({'BESS', 'PV', 'Wind'}): 23.25, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.03457, frozenset({'Wind'}): 0.0, frozenset({'BESS'}): 15.0, frozenset({'PV', 'Wind'}): 0.59836, frozenset({'BESS', 'PV'}): 15.0, frozenset({'BESS', 'Wind'}): 15.0, frozenset({'BESS', 'PV', 'Wind'}): 15.0, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.0, frozenset({'Wind'}): 2.35488, frozenset({'BESS'}): 17.9625, frozenset({'PV', 'Wind'}): 2.35488, frozenset({'BESS', 'PV'}): 17.9625, frozenset({'BESS', 'Wind'}): 18.3788, frozenset({'BESS', 'PV', 'Wind'}): 18.96014, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 0.0, frozenset({'Wind'}): 27.87185, frozenset({'BESS'}): 96.2625, frozenset({'PV', 'Wind'}): 27.87185, frozenset({'BESS', 'PV'}): 96.2625, frozenset({'BESS', 'Wind'}): 109.62261, frozenset({'BESS', 'PV', 'Wind'}): 111.05204, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 154.64658, frozenset({'Wind'}): 348.36938, frozenset({'BESS'}): 106.6875, frozenset({'PV', 'Wind'}): 470.63958, frozenset({'BESS', 'PV'}): 279.90416, frozenset({'BESS', 'Wind'}): 588.84463, frozenset({'BESS', 'PV', 'Wind'}): 796.7931, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 278.86952, frozenset({'Wind'}): 370.95869, frozenset({'BESS'}): 107.625, frozenset({'PV', 'Wind'}): 562.5163, frozenset({'BESS', 'PV'}): 419.98137, frozenset({'BESS', 'Wind'}): 621.04662, frozenset({'BESS', 'PV', 'Wind'}): 944.61306, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 240.95769, frozenset({'Wind'}): 369.4532, frozenset({'BESS'}): 106.6875, frozenset({'PV', 'Wind'}): 545.56035, frozenset({'BESS', 'PV'}): 376.57956, frozenset({'BESS', 'Wind'}): 618.02548, frozenset({'BESS', 'PV', 'Wind'}): 917.3595, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 238.14093, frozenset({'Wind'}): 353.30235, frozenset({'BESS'}): 106.6875, frozenset({'PV', 'Wind'}): 525.9527, frozenset({'BESS', 'PV'}): 373.42457, frozenset({'BESS', 'Wind'}): 595.67205, frozenset({'BESS', 'PV', 'Wind'}): 889.27128, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 239.26452, frozenset({'Wind'}): 308.50413, frozenset({'BESS'}): 106.59375, frozenset({'PV', 'Wind'}): 470.83152, frozenset({'BESS', 'PV'}): 374.58932, frozenset({'BESS', 'Wind'}): 531.81824, frozenset({'BESS', 'PV', 'Wind'}): 809.98943, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 198.25343, frozenset({'Wind'}): 343.93614, frozenset({'BESS'}): 102.84375, frozenset({'PV', 'Wind'}): 481.53129, frozenset({'BESS', 'PV'}): 324.9036, frozenset({'BESS', 'Wind'}): 578.86509, frozenset({'BESS', 'PV', 'Wind'}): 812.67076, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 150.9263, frozenset({'Wind'}): 380.88659, frozenset({'BESS'}): 100.96875, frozenset({'PV', 'Wind'}): 484.08124, frozenset({'BESS', 'PV'}): 270.01838, frozenset({'BESS', 'Wind'}): 628.13098, frozenset({'BESS', 'PV', 'Wind'}): 803.36114, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 14.49739, frozenset({'Wind'}): 117.54412, frozenset({'BESS'}): 33.5625, frozenset({'PV', 'Wind'}): 130.98996, frozenset({'BESS', 'PV'}): 49.80075, frozenset({'BESS', 'Wind'}): 196.24825, frozenset({'BESS', 'PV', 'Wind'}): 218.07881, frozenset(): 0.0}
# for time FFR + FCR-D, expected game is not superadditive.
# {frozenset({'PV'}): 3.43274, frozenset({'Wind'}): 122.13575, frozenset({'BESS'}): 34.5, frozenset({'PV', 'Wind'}): 128.83245, frozenset({'BESS', 'PV'}): 35.58366, frozenset({'BESS', 'Wind'}): 203.54075, frozenset({'BESS', 'PV', 'Wind'}): 213.47875, frozenset(): 0.0}

# %%
print(f"For {main_path}, out of {len(df_expected)} games, {superadditivity_counter} superadditive, {convexity_counter} convex and {core_non_empty_counter} non-empty core.")
# Out:
# For pics/mp_optimal_spring/, out of 168 games, 78 superadditive, 77 convex and 143 non-empty core.

# %% [markdown]
# # Reward Split with New Method

# %%
from src.game_theory_helpers import evaluate_full_game, solve_optimal_partition

# %%
df_rewards = evaluate_full_game(df_expected, df_realized, MAKE_games_superadditive=MAKE_games_superadditive,
                                MAKE_REALIZED_SUPERADDITIVE=MAKE_REALIZED_SUPERADDITIVE,
                                print_warnings=True)
# Out:
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS', 'PV'})
# Making game superadditive for: frozenset({'BESS'}), frozenset({'PV', 'Wind'})
# Making game superadditive for: frozenset({'BESS'}), frozenset({'PV', 'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS', 'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS', 'PV'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS', 'PV'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS', 'PV'})
# Making game superadditive for: frozenset({'BESS'}), frozenset({'PV', 'Wind'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS', 'PV'})
# Making game superadditive for: frozenset({'BESS'}), frozenset({'PV', 'Wind'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS', 'PV'})
# Making game superadditive for: frozenset({'BESS'}), frozenset({'PV', 'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS', 'PV'})
# Making game superadditive for: frozenset({'BESS'}), frozenset({'PV', 'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS', 'PV'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS', 'Wind'})
# Making game superadditive for: frozenset({'BESS'}), frozenset({'PV', 'Wind'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS', 'PV'})
# Making game superadditive for: frozenset({'BESS'}), frozenset({'PV', 'Wind'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS', 'PV'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS', 'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS', 'Wind'})
# Making game superadditive for: frozenset({'BESS'}), frozenset({'PV', 'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS', 'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS', 'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS', 'PV'})
# Making game superadditive for: frozenset({'BESS'}), frozenset({'PV', 'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS', 'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS', 'PV'})
# Making game superadditive for: frozenset({'BESS'}), frozenset({'PV', 'Wind'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS', 'PV'})
# Making game superadditive for: frozenset({'BESS'}), frozenset({'PV', 'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS', 'Wind'})
# Making game superadditive for: frozenset({'BESS'}), frozenset({'PV', 'Wind'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS', 'PV'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS'})
# Making game superadditive for: frozenset({'Wind'}), frozenset({'BESS', 'PV'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'Wind'})
# Making game superadditive for: frozenset({'PV'}), frozenset({'BESS'})

# %%
df_rewards.index.names = ['Index', 'Time', 'Value']

# %%
df_fc_reward = df_rewards[['PV', 'Wind', 'BESS']].xs(('Forecasted', 'Reward'), level=['Time', 'Value'])
# select only rows where all devices have non-zero forecasted reward
df_nonzero = df_fc_reward[(df_fc_reward > 0).any(axis=1)]

# %%
# print type of game for df_nonzero
nonzero_hours = df_nonzero.index.values
print("For NON-ZERO hours:")
print("For FORECASTED game:")
print(df_rewards.loc[(nonzero_hours, 'Forecasted', 'Reward'), 'Method'].value_counts())
print(f"out of {len(nonzero_hours)}.")
print("For REALIZED game:")
print(df_rewards.loc[(nonzero_hours, 'Realized', 'Reward'), 'Method'].value_counts())
print(f"out of {len(nonzero_hours)}.")
# Out:
# For NON-ZERO hours:
# For FORECASTED game:
# Method
# Shapley      160
# Nucleolus      2
# Name: count, dtype: int64
# out of 162.
# For REALIZED game:
# Method
# Shapley      160
# Nucleolus      2
# Name: count, dtype: int64
# out of 162.

# %%
hours = df_rewards.index.get_level_values(0).unique()
print("For ALL hours:")
print(df_rewards.loc[(hours, 'Realized', 'Reward'), 'Method'].value_counts())
print(f"out of {len(hours)}.")
# Out:
# For ALL hours:
# Method
# Shapley      166
# Nucleolus      2
# Name: count, dtype: int64
# out of 168.

# %%
# also show realized game
print(df_rewards.loc[(hours, 'Realized', 'Reward'), 'Method-Realized'].value_counts())
print(f"out of {len(hours)}.")
# Out:
# Method-Realized
# Shapley      151
# Nucleolus      9
# Sub-Game       8
# Name: count, dtype: int64
# out of 168.

# %%
# new multiindex
idxs1 = df_rewards.index.get_level_values(0).unique().values
idxs2 = df_rewards.index.get_level_values(1).unique().values
idxs3 = df_rewards.index.get_level_values(2).unique().values
idxs2_new = []
for i in idxs2:
    # append idx3
    for j in idxs3:
        idxs2_new.append(f'{i}-{j}')

# %%
plt.rcParams['axes.prop_cycle'] = plt.cycler(color=plt.cm.Dark2.colors[1:])

# %%
df_rewards.index = pd.MultiIndex.from_product([idxs1, idxs2_new])

# %%
df_plot = df_rewards[devices]
df_mean = df_plot.groupby(level=1).mean()
df_mean = df_mean.transpose()

# %%
# measure percentage increase of cooperative reward vs individual value
df_mean.sum()['Realized-Reward'] / df_mean.sum()['Realized-Value']
# Out:
# 1.2490407171590125

# %% [markdown]
# ### convert to latex table

# %%
from src.latex_helpers import df_to_custom_latex

dates = ['2025-04-12 11:00:00']

# %%
# convert tuples to strings for columns
N = len(devices)
def col_map(col):
    if isinstance(col, tuple):
        if len(col)==N:
            return '$N$'
        else:
            return ', '.join([str(c) for c in col])
    else:
        return str(col)

# 3. Generate LaTeX
caption_text = r"Forecasted ($\mathcal{G}_\mathbb{F}$) and Realized ($\mathcal{G}_\mathcal{R}$) Reward Game in Euros with with $\pi(t)=6$€/MW on 9.4.2025 at 9AM"
label_text = "tab:non_empty_core_game"

for date in dates:
    latex_forecasted = df_to_custom_latex(df_expected.xs(date, level=1), caption_text, label_text, col_map=col_map)
    print(latex_forecasted)
    latex_output = df_to_custom_latex(df_realized.xs(date, level=1), caption_text, label_text, col_map=col_map)
    print(latex_output)
# Out:
# \begin{table}[ht]
#   \centering
#   \resizebox{0.5\textwidth}{!}{%
#     \begin{tabular}{l|lllllll}
#     \toprule
#     & PV & Wind & BESS & PV, Wind & PV, BESS & Wind, BESS & $N$ \\
#     \midrule
#     FFR + FCR-D & 241.0 & 369.5 & 106.7 & 545.6 & 376.6 & 618.0 & 917.4 \\
#     \bottomrule
#     \end{tabular}%
#   }
#   \vspace{.1cm}
#   \caption{Forecasted ($\mathcal{G}_\mathbb{F}$) and Realized ($\mathcal{G}_\mathcal{R}$) Reward Game in Euros with with $\pi(t)=6$€/MW on 9.4.2025 at 9AM}
#   \label{tab:non_empty_core_game}
# \end{table}
# \begin{table}[ht]
#   \centering
#   \resizebox{0.5\textwidth}{!}{%
#     \begin{tabular}{l|lllllll}
#     \toprule
#     & PV & Wind & BESS & PV, Wind & PV, BESS & Wind, BESS & $N$ \\
#     \midrule
#     FFR + FCR-D & 303.8 & 444.0 & 106.7 & 644.3 & 446.9 & 721.2 & 1061.5 \\
#     \bottomrule
#     \end{tabular}%
#   }
#   \vspace{.1cm}
#   \caption{Forecasted ($\mathcal{G}_\mathbb{F}$) and Realized ($\mathcal{G}_\mathcal{R}$) Reward Game in Euros with with $\pi(t)=6$€/MW on 9.4.2025 at 9AM}
#   \label{tab:non_empty_core_game}
# \end{table}

# %%
df_rewards
# Out:
#                                              PV       Wind       BESS  \
# 2025-04-06 00:00:00 Forecasted-Value        0.0        0.0   94.59375
#                     Forecasted-Reward       0.0        0.0   94.59375
#                     Realized-Value          0.0        0.0   94.59375
#                     Realized-Reward         0.0   4.290665  98.884415
# 2025-04-06 01:00:00 Forecasted-Value        0.0        0.0   94.40625
# ...                                         ...        ...        ...
# 2025-04-12 22:00:00 Realized-Reward         0.0   16.29572   13.87504
# 2025-04-12 23:00:00 Forecasted-Value        0.0   12.61005      9.375
#                     Forecasted-Reward  0.040098  15.071533  11.804558
#                     Realized-Value          0.0   18.20547      9.375
#                     Realized-Reward         0.0  21.701285  12.870815
#
#                                         Method Method-Realized
# 2025-04-06 00:00:00 Forecasted-Value   Shapley         Shapley
#                     Forecasted-Reward  Shapley         Shapley
#                     Realized-Value     Shapley         Shapley
#                     Realized-Reward    Shapley         Shapley
# 2025-04-06 01:00:00 Forecasted-Value   Shapley         Shapley
# ...                                        ...             ...
# 2025-04-12 22:00:00 Realized-Reward    Shapley         Shapley
# 2025-04-12 23:00:00 Forecasted-Value   Shapley         Shapley
#                     Forecasted-Reward  Shapley         Shapley
#                     Realized-Value     Shapley         Shapley
#                     Realized-Reward    Shapley         Shapley
#
# [672 rows x 5 columns]

# %% [markdown]
# ## Main Reward Plot

# %%
# define colors
device_colors = {
    'PV': (217/255, 95/255, 2/255),
    'Wind': (117/255, 112/255, 179/255),
    'BESS': (231/255, 41/255, 138/255)
}

# 3. Create the Plot
fig, ax = plt.subplots(figsize=(8, 5))
df_mean.plot(kind='bar', ax=ax, width=0.8, edgecolor='black', linewidth=0.5)

for col_idx, container in enumerate(ax.containers):
    # --- Determine Style per Column ---
    alpha = 1.0
    hatch = None
    
    # "bars 1 and 2 should be alpha=.5" -> indices 0 and 1
    if col_idx in [0, 1]:
        alpha = 0.33
        
    # "bars 2 and 4 should be hatch='//'" -> indices 1 and 3
    if col_idx in [1, 3]:
        hatch = '//'
        
    # --- Apply to each bar in the group ---
    # We zip with df_mean.index to know which device (PV/Wind/BESS) the bar belongs to
    for bar, label in zip(container, df_mean.index):
        # Set Color based on device (row index)
        color = device_colors.get(label)
        bar.set_facecolor(color)
        
        # Set Alpha
        bar.set_alpha(alpha)
        
        # Set Hatch
        bar.set_hatch(hatch)

# Final Formatting
ax.set_ylabel(r"Value (€)")
ax.set_title(r"Average Forecasted and Realized Rewards")
plt.xticks(rotation=0) # Keep labels horizontal
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left') # Move legend out
legend_handles = []
for i, col in enumerate(df_mean.columns):
    hatch = '//' if i in [1, 3] else None
    alpha = 0.33 if i in [0, 1] else 1.0
    legend_handles.append(
        mpatches.Patch(facecolor='lightgrey', edgecolor='black',
                       hatch=hatch, alpha=alpha, label=col)
    )
ax.legend(handles=legend_handles, bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.grid()
plt.savefig('pics/average_forecasted_and_realized_rewards.png', dpi=600, bbox_inches='tight')

# %%
def assess_distribution_fit(data, distributions_to_test):
    """
    Fits and compares distributions using the Maximum Likelihood Estimation 
    (MLE) for fitting and the Kolmogorov-Smirnov (KS) test for scoring.
    """
    results = []
    
    # 💡 The list of distributions you want to check
    # Other common choices: 'weibull_min', 'lognorm', 'gamma', 'beta'
    
    for dist_name in distributions_to_test:
        dist = getattr(stats, dist_name)
        
        try:
            # 1. Fit the parameters using Maximum Likelihood Estimation (MLE)
            params = dist.fit(data)
            
            # 2. Perform the KS test to compare the data to the fitted distribution
            # H0: The data comes from the specified distribution
            ks_stat, p_value = stats.kstest(data, dist_name, args=params)
            
            results.append({
                'Distribution': dist_name,
                'KS Statistic': ks_stat, # Lower is better
                'P-Value': p_value      # Higher (ideally > 0.05) is better
            })
        except Exception:
            # Catch distributions that might fail to converge on parameters
            results.append({'Distribution': dist_name, 'KS Statistic': np.nan, 'P-Value': np.nan})
            
    # Sort by the KS Statistic to find the best fit quickly
    df = pd.DataFrame(results).sort_values(by='KS Statistic', ascending=True)
    
    # 
    
    return df

# Example Usage (Use your actual data instead of this random sample)
data = np.random.normal(loc=5, scale=1.5, size=100)
test_dists = ['norm', 't', 'laplace', 'expon']

fit_results = assess_distribution_fit(data, test_dists)
print(fit_results)
# Out:
#   Distribution  KS Statistic       P-Value
# 1            t      0.053465  9.226534e-01
# 0         norm      0.053746  9.197887e-01
# 2      laplace      0.080728  5.066214e-01
# 3        expon      0.347120  2.858015e-11

# %%
# only plot rewad, not values
df_plot_2 = df_rewards.loc(axis=0)[:, ['Forecasted-Reward', 'Realized-Reward']]

# make 4 subplots axis
fig, axs = plt.subplots(1,2, figsize=(12, 5))

for i, x in enumerate(df_plot_2.index.get_level_values(1).unique().values):
    sns.histplot(df_plot_2.loc(axis=0)[:, x], bins=60, ax=axs[i])
    axs[i].set_title(f'Histogram of {x}')
    axs[i].set_xlabel(f'{x} (€)')
    
    # fit_results = assess_distribution_fit([x for xs in df_plot.loc(axis=0)[:, x].values for x in xs], test_dists)
    # print(fit_results)
    # print the numer of values above
    vals = [xs for x in df_plot_2.loc(axis=0)[:, x].values for xs in x[:3]]
    thresh = 46.3
    above_thresh, above_count = sum(v for v in vals if v > thresh), sum(1 for v in vals if v > thresh)
    below_thresh, below_count = sum(v for v in vals if 0 <= v <= thresh), sum(1 for v in vals if 0 <= v <= thresh)
    print(f'For {x}, {above_thresh:.1f} values above {thresh}, {below_thresh:.1f} values below or equal to {thresh}.')
    print(f'For {x}, {above_count} counts above {thresh}, {below_count} counts below or equal to {thresh}.')
    print(f'{100*above_count/(above_count+below_count):.2f}% of values make up {100*above_thresh/(above_thresh+below_thresh):.2f}% of the total reward.')

plt.savefig('pics/reward_histograms.png', dpi=600, bbox_inches='tight')
# Out:
# For Forecasted-Reward, 13733.2 values above 46.3, 2960.9 values below or equal to 46.3.
# For Forecasted-Reward, 88 counts above 46.3, 416 counts below or equal to 46.3.
# 17.46% of values make up 82.26% of the total reward.
# For Realized-Reward, 16517.7 values above 46.3, 3212.3 values below or equal to 46.3.
# For Realized-Reward, 97 counts above 46.3, 385 counts below or equal to 46.3.
# 20.12% of values make up 83.72% of the total reward.

# %%
df_exp_real = dvpps_infos[service].groupby(level=0)[['expected_reward', 'real_reward']].mean()
# df_exp_real['diff'] = df_exp_real['real_reward'] - df_exp_real['expected_reward']
df_exp_real.plot.bar(figsize=(10,6))
# set x axis labels as only start and end time and 5 time points in between
plt.xticks([0, len(df_exp_real)-1], [df_exp_real.index[0], df_exp_real.index[-1]])
plt.show()

# %% [markdown]
# ## compare to other BESS size

# %%
# get PATH
path_BESS = 'pics/mp_optimal_spring/'
# get data
opt_df_expected = pd.read_csv(f'{path_BESS}expected_values_DPF.csv', index_col=[0,1], header=[0,1,2])
opt_df_expected.columns = [tuple(c for c in col if c!='nan') for col in opt_df_expected.columns.values]
opt_df_realized = pd.read_csv(f'{path_BESS}values_DPF.csv', index_col=[0,1], header=[0,1,2])
opt_df_realized.columns = [tuple(c for c in col if c!='nan') for col in opt_df_realized.columns.values]
# evaluate rewards
opt_df_rewards = evaluate_full_game(opt_df_expected, opt_df_realized, MAKE_games_superadditive=MAKE_games_superadditive,
                                MAKE_REALIZED_SUPERADDITIVE=MAKE_REALIZED_SUPERADDITIVE,
                                print_warnings=False)

# %%
df_compare = pd.DataFrame(columns=devices, index=['Ilmar Power Plant', 'Ilmar + Large BESS'])
# get optimal rewards
opt_rewards = opt_df_rewards.xs('Realized', level=1)[devices].groupby(level=1).mean()
df_compare.loc['Ilmar + Large BESS'] = opt_rewards.loc['Reward']
df_compare.loc['Ilmar Power Plant'] = df_rewards[devices].groupby(level=1).mean().loc['Realized-Reward']

# %%
df_compare = df_compare.transpose()

# %%
# plot df_compare in bar plot
fig, ax = plt.subplots(figsize=(8, 5))
df_compare.plot(kind='bar', ax=ax, width=0.8, edgecolor='black', linewidth=0.5)

for col_idx, container in enumerate(ax.containers):
    # --- Determine Style per Column ---
    alpha = 1.0
    hatch = None
    
    # # "bars 1 and 2 should be alpha=.5" -> indices 0 and 1
    # if col_idx in [0, 1]:
    #     alpha = 0.5
        
    # "bars 2 and 4 should be hatch='//'" -> indices 1 and 3
    if col_idx in [1, 3]:
        hatch = '//'
        
    # --- Apply to each bar in the group ---
    # We zip with df_mean.index to know which device (PV/Wind/BESS) the bar belongs to
    for bar, label in zip(container, df_compare.index):
        # Set Color based on device (row index)
        color = device_colors.get(label)
        bar.set_facecolor(color)
        
        # Set Alpha
        bar.set_alpha(alpha)
        
        # Set Hatch
        bar.set_hatch(hatch)

baseline_col = 'Ilmar Power Plant'
comp_col = 'Ilmar + Large BESS'
# annotate above the right bars (comp_col)
for bar, label in zip(ax.containers[1], df_compare.index):  # right bars = comparison
    base = df_compare.loc[label, baseline_col]
    comp = df_compare.loc[label, comp_col]
    if base != 0:
        pct = (comp - base) / abs(base) * 100
        ax.annotate(f'+{pct:.0f}%',
                    xy=(bar.get_x() + bar.get_width()/2, bar.get_height()),
                    xytext=(0, 5),
                    textcoords='offset points',
                    ha='center', va='bottom', fontsize=10, color='k')

# Final Formatting
ax.set_ylabel(r"Value (€)")
ax.set_title(r"Ilmar vs Large BESS Reward Comparison")
ax.set_ylim(0, df_compare.values.max()*1.1)  # add some space on top for annotations
plt.xticks(rotation=0) # Keep labels horizontal
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left') # Move legend out
# plt.legend()
handles = [
    mpatches.Patch(facecolor='lightgrey', edgecolor='black', label='Ilmar Power Plant'),
    mpatches.Patch(facecolor='lightgrey', edgecolor='black', hatch='//', label='Ilmar + Large BESS')
]
ax.legend(handles=handles, loc='upper left')
plt.xticks(rotation=0) # Keep labels horizontal
# plt.grid()
plt.savefig('pics/Ilmar_vs_large_bess.png', dpi=600, bbox_inches='tight')

# %% [markdown]
# ## compare to other K values

# %%
Ks = [3, 7, 25]
# get PATH
path_BESS = 'pics/mp_low_k/'
# get data
opt_df_expected = pd.read_csv(f'{path_BESS}expected_values_DPF.csv', index_col=[0,1], header=[0,1,2])
opt_df_expected.columns = [tuple(c for c in col if c!='nan') for col in opt_df_expected.columns.values]
opt_df_realized = pd.read_csv(f'{path_BESS}values_DPF.csv', index_col=[0,1], header=[0,1,2])
opt_df_realized.columns = [tuple(c for c in col if c!='nan') for col in opt_df_realized.columns.values]
# evaluate rewards
opt_df_rewards = evaluate_full_game(opt_df_expected, opt_df_realized, MAKE_games_superadditive=MAKE_games_superadditive,
                                MAKE_REALIZED_SUPERADDITIVE=MAKE_REALIZED_SUPERADDITIVE,
                                print_warnings=False)
# get PATH
# path_BESS = 'pics/mp_mid_k/'
path_BESS = 'pics/mp_k7/'
# get data
opt_df_expected = pd.read_csv(f'{path_BESS}expected_values_DPF.csv', index_col=[0,1], header=[0,1,2])
opt_df_expected.columns = [tuple(c for c in col if c!='nan') for col in opt_df_expected.columns.values]
opt_df_realized = pd.read_csv(f'{path_BESS}values_DPF.csv', index_col=[0,1], header=[0,1,2])
opt_df_realized.columns = [tuple(c for c in col if c!='nan') for col in opt_df_realized.columns.values]
# evaluate rewards
mid_k_rewards = evaluate_full_game(opt_df_expected, opt_df_realized, MAKE_games_superadditive=MAKE_games_superadditive,
                                MAKE_REALIZED_SUPERADDITIVE=MAKE_REALIZED_SUPERADDITIVE,
                                print_warnings=False)

# %%
df_compare = pd.DataFrame(columns=devices, index=[f'Ilmar; K={k}' for k in Ks])
# get optimal rewards
opt_rewards = opt_df_rewards.xs('Realized', level=1)[devices].groupby(level=1).mean()
df_compare.loc[f'Ilmar; K={Ks[0]}'] = opt_rewards.loc['Reward']
df_compare.loc[f'Ilmar; K={Ks[2]}'] = df_rewards[devices].groupby(level=1).mean().loc['Realized-Reward']
k10_rewards = mid_k_rewards.xs('Realized', level=1)[devices].groupby(level=1).mean()
df_compare.loc[f'Ilmar; K={Ks[1]}'] = k10_rewards.loc['Reward']

# %%
df_compare = df_compare.transpose()

# %%
df_compare.sum()
# Out:
# Ilmar; K=3      61.488273
# Ilmar; K=7     116.485522
# Ilmar; K=25    116.284365
# dtype: object

# %%
# plot df_compare in bar plot
fig, ax = plt.subplots(figsize=(8, 5))
df_compare.plot(kind='bar', ax=ax, width=0.8, edgecolor='black', linewidth=0.5)

for col_idx, container in enumerate(ax.containers):
    # --- Determine Style per Column ---
    alpha = 1.0
    hatch = None
        
    # last bar should be hatch
    if col_idx in [0]:
        alpha = 0.33
    if col_idx in [2]:
        hatch = '//'
        
    # --- Apply to each bar in the group ---
    # We zip with df_mean.index to know which device (PV/Wind/BESS) the bar belongs to
    for bar, label in zip(container, df_compare.index):
        # Set Color based on device (row index)
        color = device_colors.get(label)
        bar.set_facecolor(color)
        
        # Set Alpha
        bar.set_alpha(alpha)
        
        # Set Hatch
        bar.set_hatch(hatch)

# Final Formatting
ax.set_ylabel(r"Value (€)")
ax.set_title(r"Ilmar Reward Comparison for K Scenarios")
plt.xticks(rotation=0) # Keep labels horizontal
handles = [
    mpatches.Patch(facecolor='lightgrey', edgecolor='black', alpha=.33, label=f'Ilmar; K={Ks[0]}'),
    mpatches.Patch(facecolor='lightgrey', edgecolor='black', label=f'Ilmar; K={Ks[1]}'),
    mpatches.Patch(facecolor='lightgrey', edgecolor='black', hatch='//', label=f'Ilmar; K={Ks[2]}')
]
ax.legend(handles=handles)
# plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left') # Move legend out
plt.tight_layout()
plt.grid()
# plt.savefig('custom_bar_plot.png')

# %% [markdown]
# ## compare to other seasons

# %%
path2 = 'pics/mp_ilmar_summer/'
path3 = 'pics/mp_ilmar_autumn/'

# TODO

# %% [markdown]
# ## Analyze some individual games

# %%
from src.get_optimal_bid import get_optimal_bid
import numpy as np

# %%
# Get the Tab20 colormap
cmap = plt.cm.get_cmap("tab20")
# Extract the first 4 colors
base_colors = [cmap(i) for i in range(10)]
# Create extended cycle: first full alpha, then alpha=0.5
# colors = base_colors + [(r, g, b, 0.5) for (r, g, b, _) in base_colors]
# Set this as default color cycle
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=colors)
# Out:
# C:\Users\carlv\AppData\Local\Temp\ipykernel_32452\216728504.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = plt.cm.get_cmap("tab20")

# %%
# load bids dataframe
df_bids = pd.read_csv(f'{main_path}/bids_DPF_{service}.csv', index_col=[0,1], parse_dates=True, date_format='%Y-%m-%d %H:%M:%S')

# %%
def map_idx_to_datetime(idx):
    vals = dvpps_infos[service].index.get_level_values(0).unique().values
    return pd.Timestamp(vals[idx])
def map_datetime_to_idx(dt):
    vals = dvpps_infos[service].index.get_level_values(0).unique().values
    for i, v in enumerate(vals):
        if v == dt:
            return i
    return None

# %%
dict_idxs = {}
dict_realized_type_game = {}
for type_game in GAME_types_to_plot:
    dict_idxs[type_game] = df_rewards[df_rewards['Method']==type_game].index.get_level_values(0).unique()
    dict_realized_type_game[type_game] = df_rewards.loc[(dict_idxs[type_game], 'Realized-Reward'), 'Method-Realized'].values
    dict_idxs[type_game] = pd.to_datetime(dict_idxs['Shapley'])

# %%
def bid_value(bids, rho, bid,
              return_prob=False):
    gamma = sum(rho for b in bids if b >= bid)
    if return_prob:
        return gamma
    return bid * (4 * gamma - 3)

# %%
def bids_to_values(bids, rho, return_prob=False) -> np.ndarray:
    values = np.array([bid_value(bids, rho, b, return_prob=False) for b in bids])
    if not return_prob:
        return values
    else:
        gammas = np.array([bid_value(bids, rho, b, return_prob=True) for b in bids])
        return gammas, values

# %%
cols = df_bids.columns
idx_tuples = [eval(col) for col in df_bids.columns.values]
idx_frozensets = [frozenset(tup) for tup in idx_tuples]
the_map = {fs: col for fs, col in zip(idx_frozensets, cols)}

# %%
MAP_METHOD_TO_TYPE = {'Shapley': 'Convex', 'Nucleolus': 'Supperadditive/Non-Empty Core', 'Sub-Game': 'Empty Core'}

# %% [markdown]
# ## individual times plotting

# %%
MAX_GAMES_TO_PLOT = 10  # max games per type to plot

type_game = 'Shapley'
# if len(dict_idxs[type_game]) == 0:
#     continue
if len(dict_idxs[type_game]) < MAX_GAMES_TO_PLOT:
    MAX_GAMES_TO_PLOT = len(dict_idxs[type_game])

# pick 5 random indexes
np.random.seed(42)
these_idxs = np.random.choice(len(dict_idxs[type_game]), size=MAX_GAMES_TO_PLOT, replace=False)

dt_idxs = dict_idxs[type_game][these_idxs]
realized_methods = dict_realized_type_game[type_game][these_idxs]

K_errors = len(df_bids.loc[dt_idxs[0]])
probs = [1/K_errors for _ in range(K_errors)]
for j, dt in enumerate(dt_idxs):
    # print(dvpps_infos[service].loc[dt])
    # visualize mean and std of each column
    plt.figure()
    plt.title(f'Forecasted: {type_game}, Realized: {MAP_METHOD_TO_TYPE[realized_methods[j]]} at day {dt.day} hour {dt.hour}')
    df_bids.loc[dt].mean(axis=0).plot(kind='bar', label='Mean Bid')
    # plot min max with error bars
    plt.errorbar(x=df_bids.loc[dt].columns, y=df_bids.loc[dt].mean(axis=0), yerr=df_bids.loc[dt].std(axis=0), fmt='o', label='Std Dev',
                color=base_colors[1])
    # compute optimal bid for each coalition and plot as star marker
    dict_opt_bids = {}
    for coalition in df_bids.loc[dt].columns:
        c_bids = np.squeeze(df_bids.loc[dt, [coalition]].values)
        b_star_coalition, value_wo_price, gamma = get_optimal_bid(c_bids, probs, return_reward=True)
        dict_opt_bids[coalition] = b_star_coalition
        # plot as star marker
        plt.plot(coalition, b_star_coalition, marker='*', markersize=7, label='Optimal Bid' if coalition==df_bids.loc[dt].columns[0] else "", color=base_colors[2])
        # annotate value of optimal bid to the right of the star
        plt.annotate(f'{b_star_coalition:.2f}', (coalition, b_star_coalition), textcoords="offset points", xytext=(12, 0), ha='center', fontsize=10)
    plt.ylabel('Bid Value (€)')
    plt.grid()
    plt.legend()

    # next, also plot th eindividual bids in line chart for non-superadditiv coalitions
    idx_str = str(dt)        
    v = {frozenset(k): val for k, val in df_expected.loc[(service, idx_str)].items()}
    v[frozenset()] = 0.0  # ensure empty set has value 0
    max_value, coalitions = solve_optimal_partition(v)
    print(f'At hour {dt}, optimal partition is {coalitions} with value {max_value}.')
    # plot line chart for this coalition
    plt.figure()
    x_ks = np.arange(K_errors)
    # add grand coalition
    coalitions.append(frozenset(players))

    for coalition in coalitions:
        # convert to columns
        col = the_map[coalition]
        the_bids = df_bids.loc[dt, col].values.tolist()
        the_bids.sort()
        # the_bids = the_bids[::-1]
        # convert bids to values
        vals = bids_to_values(the_bids, probs[0])
        # indicate dict_opt_bids in plot
        plt.plot(x_ks, vals, marker='o', label=f'Coalition {set(coalition)}')
        # print idx and bid of max value
        max_idx = np.argmax(vals)
        print(f"Coalition {coalition} max value at index {max_idx}, bid: {the_bids[max_idx]:.3f}, value: {vals[max_idx]:.3f}")

    # print forecasted and realized game values and reward splits
    print("Forecasted Game Values:")
    print(df_expected.loc[(service, idx_str)])
    print("Realized Game Values:")
    print(df_realized.loc[(service, idx_str)])
    print("Forecasted and Realized rewards:")
    print(df_rewards.loc[idx_str])

    plt.xlabel('Bid Index (sorted)')
    plt.ylabel('Value')
    plt.title('R_E(b) vs Bid')
    plt.grid(True)
    plt.xlim((0, 8))
    plt.legend()
    plt.show()
# Out:
# At hour 2025-04-10 06:00:00, optimal partition is [frozenset({'BESS', 'Wind', 'PV'})] with value 10.2772.
# Coalition frozenset({'BESS', 'Wind', 'PV'}) max value at index 0, bid: 8.222, value: 8.222
# Coalition frozenset({'BESS', 'PV', 'Wind'}) max value at index 0, bid: 8.222, value: 8.222
# Forecasted Game Values:
# (PV,)                4.73463
# (Wind,)              0.00000
# (BESS,)              4.68750
# (PV, Wind)           3.28836
# (PV, BESS)           9.99067
# (Wind, BESS)         4.68750
# (PV, Wind, BESS)    10.27720
# Name: (FFR + FCR-D, 2025-04-10 06:00:00), dtype: float64
# Realized Game Values:
# (PV,)                6.26413
# (Wind,)              0.00000
# (BESS,)              4.68750
# (PV, Wind)           6.14143
# (PV, BESS)          11.70383
# (Wind, BESS)         7.49391
# (PV, Wind, BESS)    14.51024
# Name: (FFR + FCR-D, 2025-04-10 06:00:00), dtype: float64
# Forecasted and Realized rewards:
#                         PV      Wind      BESS   Method Method-Realized
# Forecasted-Value   4.73463       0.0    4.6875  Shapley         Shapley
# Forecasted-Reward  5.11441   0.09551   5.06728  Shapley         Shapley
# Realized-Value     6.26413       0.0    4.6875  Shapley         Shapley
# Realized-Reward    6.64023  1.403205  6.466805  Shapley         Shapley
# At hour 2025-04-11 18:00:00, optimal partition is [frozenset({'BESS', 'Wind', 'PV'})] with value 15.0.
# Coalition frozenset({'BESS', 'Wind', 'PV'}) max value at index 0, bid: 3.750, value: 3.750
# Coalition frozenset({'BESS', 'PV', 'Wind'}) max value at index 0, bid: 3.750, value: 3.750
# Forecasted Game Values:
# (PV,)                0.0
# (Wind,)              0.0
# (BESS,)             15.0
# (PV, Wind)           0.0
# (PV, BESS)          15.0
# (Wind, BESS)        15.0
# (PV, Wind, BESS)    15.0
# Name: (FFR + FCR-D, 2025-04-11 18:00:00), dtype: float64
# Realized Game Values:
# (PV,)                0.00000
# (Wind,)              0.00000
# (BESS,)             15.00000
# (PV, Wind)           0.00000
# (PV, BESS)          15.00000
# (Wind, BESS)        17.66073
# (PV, Wind, BESS)    17.66073
# Name: (FFR + FCR-D, 2025-04-11 18:00:00), dtype: float64
# Forecasted and Realized rewards:
#                     PV      Wind       BESS   Method Method-Realized
# Forecasted-Value   0.0       0.0       15.0  Shapley         Shapley
# Forecasted-Reward  0.0       0.0       15.0  Shapley         Shapley
# Realized-Value     0.0       0.0       15.0  Shapley         Shapley
# Realized-Reward    0.0  1.330365  16.330365  Shapley         Shapley
# At hour 2025-04-09 08:00:00, optimal partition is [frozenset({'BESS', 'Wind', 'PV'})] with value 52.42876.
# Coalition frozenset({'BESS', 'Wind', 'PV'}) max value at index 0, bid: 29.959, value: 29.959
# Coalition frozenset({'BESS', 'PV', 'Wind'}) max value at index 0, bid: 29.959, value: 29.959
# Forecasted Game Values:
# (PV,)                9.89574
# (Wind,)             23.59638
# (BESS,)              6.56250
# (PV, Wind)          31.48657
# (PV, BESS)          17.64653
# (Wind, BESS)        39.22084
# (PV, Wind, BESS)    52.42876
# Name: (FFR + FCR-D, 2025-04-09 08:00:00), dtype: float64
# Realized Game Values:
# (PV,)               14.60167
# (Wind,)            -69.28863
# (BESS,)              6.56250
# (PV, Wind)          32.66622
# (PV, BESS)          22.91755
# (Wind, BESS)        39.22084
# (PV, Wind, BESS)    54.84413
# Name: (FFR + FCR-D, 2025-04-09 08:00:00), dtype: float64
# Forecasted and Realized rewards:
#                           PV       Wind       BESS   Method Method-Realized
# Forecasted-Value     9.89574   23.59638     6.5625  Shapley       Nucleolus
# Forecasted-Reward  11.197848  28.835323  12.395588  Shapley       Nucleolus
# Realized-Value      14.60167  -69.28863     6.5625  Shapley       Nucleolus
# Realized-Reward     15.23444 -18.559065  58.168755  Shapley       Nucleolus
# At hour 2025-04-08 09:00:00, optimal partition is [frozenset({'BESS', 'Wind', 'PV'})] with value 12.53119.
# Coalition frozenset({'BESS', 'Wind', 'PV'}) max value at index 0, bid: 10.025, value: 10.025
# Coalition frozenset({'BESS', 'PV', 'Wind'}) max value at index 0, bid: 10.025, value: 10.025
# Forecasted Game Values:
# (PV,)                7.00279
# (Wind,)              0.00000
# (BESS,)              4.68750
# (PV, Wind)           4.59315
# (PV, BESS)          12.53119
# (Wind, BESS)         4.68750
# (PV, Wind, BESS)    12.53119
# Name: (FFR + FCR-D, 2025-04-08 09:00:00), dtype: float64
# Realized Game Values:
# (PV,)                8.02816
# (Wind,)              0.00000
# (BESS,)              4.68750
# (PV, Wind)           5.31885
# (PV, BESS)          13.67969
# (Wind, BESS)         4.76432
# (PV, Wind, BESS)    13.75651
# Name: (FFR + FCR-D, 2025-04-08 09:00:00), dtype: float64
# Forecasted and Realized rewards:
#                          PV     Wind      BESS   Method Method-Realized
# Forecasted-Value    7.00279      0.0    4.6875  Shapley         Shapley
# Forecasted-Reward   7.42324      0.0   5.10795  Shapley         Shapley
# Realized-Value      8.02816      0.0    4.6875  Shapley         Shapley
# Realized-Reward    8.510175  0.03841  5.207925  Shapley         Shapley
# At hour 2025-04-10 03:00:00, optimal partition is [frozenset({'BESS', 'Wind', 'PV'})] with value 6.16839.
# Coalition frozenset({'BESS', 'Wind', 'PV'}) max value at index 0, bid: 12.337, value: 12.337
# Coalition frozenset({'BESS', 'PV', 'Wind'}) max value at index 0, bid: 12.337, value: 12.337
# Forecasted Game Values:
# (PV,)               0.00000
# (Wind,)             3.22476
# (BESS,)             1.87500
# (PV, Wind)          3.23365
# (PV, BESS)          1.87500
# (Wind, BESS)        6.03820
# (PV, Wind, BESS)    6.16839
# Name: (FFR + FCR-D, 2025-04-10 03:00:00), dtype: float64
# Realized Game Values:
# (PV,)               0.00000
# (Wind,)             4.10349
# (BESS,)             1.87500
# (PV, Wind)          4.10349
# (PV, BESS)          1.87500
# (Wind, BESS)        7.55440
# (PV, Wind, BESS)    7.55440
# Name: (FFR + FCR-D, 2025-04-10 03:00:00), dtype: float64
# Forecasted and Realized rewards:
#                          PV      Wind      BESS   Method Method-Realized
# Forecasted-Value        0.0   3.22476     1.875  Shapley         Shapley
# Forecasted-Reward  0.044878  3.738858  2.384653  Shapley         Shapley
# Realized-Value          0.0   4.10349     1.875  Shapley         Shapley
# Realized-Reward         0.0  4.891445  2.662955  Shapley         Shapley
# Bids are invalid (max bid: 0.711, mean bid: -0.160), submitting 0 bid (not participating).
# At hour 2025-04-07 06:00:00, optimal partition is [frozenset({'BESS', 'Wind', 'PV'})] with value 5.40843.
# Coalition frozenset({'BESS', 'Wind', 'PV'}) max value at index 0, bid: 7.211, value: 7.211
# Coalition frozenset({'BESS', 'PV', 'Wind'}) max value at index 0, bid: 7.211, value: 7.211
# Forecasted Game Values:
# (PV,)               2.20237
# (Wind,)             0.00000
# (BESS,)             2.81250
# (PV, Wind)          1.52014
# (PV, BESS)          5.27933
# (Wind, BESS)        2.81250
# (PV, Wind, BESS)    5.40843
# Name: (FFR + FCR-D, 2025-04-07 06:00:00), dtype: float64
# Realized Game Values:
# (PV,)               3.34601
# (Wind,)             0.00000
# (BESS,)             2.81250
# (PV, Wind)          2.87299
# (PV, BESS)          6.56030
# (Wind, BESS)        3.74754
# (PV, Wind, BESS)    7.49535
# Name: (FFR + FCR-D, 2025-04-07 06:00:00), dtype: float64
# Forecasted and Realized rewards:
#                          PV      Wind      BESS   Method Method-Realized
# Forecasted-Value    2.20237       0.0    2.8125  Shapley         Shapley
# Forecasted-Reward  2.377633  0.043033  2.987763  Shapley         Shapley
# Realized-Value      3.34601       0.0    2.8125  Shapley         Shapley
# Realized-Reward    3.546908  0.467523  3.480918  Shapley         Shapley
# At hour 2025-04-10 10:00:00, optimal partition is [frozenset({'BESS', 'Wind', 'PV'})] with value 18.33331.
# Coalition frozenset({'BESS', 'Wind', 'PV'}) max value at index 0, bid: 9.167, value: 9.167
# Coalition frozenset({'BESS', 'PV', 'Wind'}) max value at index 0, bid: 9.167, value: 9.167
# Forecasted Game Values:
# (PV,)                9.67190
# (Wind,)              0.00000
# (BESS,)              7.50000
# (PV, Wind)           6.34383
# (PV, BESS)          18.33331
# (Wind, BESS)         7.50000
# (PV, Wind, BESS)    18.33331
# Name: (FFR + FCR-D, 2025-04-10 10:00:00), dtype: float64
# Realized Game Values:
# (PV,)               12.12478
# (Wind,)              0.00000
# (BESS,)              7.50000
# (PV, Wind)           8.92114
# (PV, BESS)          21.08074
# (Wind, BESS)         8.83261
# (PV, Wind, BESS)    22.41335
# Name: (FFR + FCR-D, 2025-04-10 10:00:00), dtype: float64
# Forecasted and Realized rewards:
#                           PV      Wind      BESS   Method Method-Realized
# Forecasted-Value      9.6719       0.0       7.5  Shapley         Shapley
# Forecasted-Reward  10.252605       0.0  8.080705  Shapley         Shapley
# Realized-Value      12.12478       0.0       7.5  Shapley         Shapley
# Realized-Reward     12.85276  0.666305  8.894285  Shapley         Shapley
# At hour 2025-04-09 12:00:00, optimal partition is [frozenset({'BESS', 'Wind', 'PV'})] with value 255.56731.
# Coalition frozenset({'BESS', 'Wind', 'PV'}) max value at index 0, bid: 25.582, value: 25.582
# Coalition frozenset({'BESS', 'PV', 'Wind'}) max value at index 0, bid: 25.582, value: 25.582
# Forecasted Game Values:
# (PV,)                47.71769
# (Wind,)             114.72657
# (BESS,)              37.46250
# (PV, Wind)          149.92250
# (PV, BESS)           90.91016
# (Wind, BESS)        196.24865
# (PV, Wind, BESS)    255.56731
# Name: (FFR + FCR-D, 2025-04-09 12:00:00), dtype: float64
# Realized Game Values:
# (PV,)                48.96453
# (Wind,)             155.90880
# (BESS,)              37.46250
# (PV, Wind)          188.22071
# (PV, BESS)           92.30673
# (Wind, BESS)        253.24650
# (PV, Wind, BESS)    308.09073
# Name: (FFR + FCR-D, 2025-04-09 12:00:00), dtype: float64
# Forecasted and Realized rewards:
#                           PV       Wind       BESS   Method Method-Realized
# Forecasted-Value    47.71769  114.72657    37.4625  Shapley         Shapley
# Forecasted-Reward  52.539675  138.71336  64.314275  Shapley         Shapley
# Realized-Value      48.96453   155.9088    37.4625  Shapley         Shapley
# Realized-Reward     51.90438   185.8464   70.33995  Shapley         Shapley
# Bids are invalid (max bid: 0.559, mean bid: -0.208), submitting 0 bid (not participating).
# At hour 2025-04-12 20:00:00, optimal partition is [frozenset({'BESS', 'Wind', 'PV'})] with value 62.38889.
# Coalition frozenset({'BESS', 'Wind', 'PV'}) max value at index 0, bid: 8.732, value: 8.732
# Coalition frozenset({'BESS', 'PV', 'Wind'}) max value at index 0, bid: 8.732, value: 8.732
# Forecasted Game Values:
# (PV,)                0.00000
# (Wind,)             25.71829
# (BESS,)             26.79375
# (PV, Wind)          25.71829
# (PV, BESS)          26.79375
# (Wind, BESS)        62.38889
# (PV, Wind, BESS)    62.38889
# Name: (FFR + FCR-D, 2025-04-12 20:00:00), dtype: float64
# Realized Game Values:
# (PV,)                0.00000
# (Wind,)             36.28214
# (BESS,)             26.79375
# (PV, Wind)          36.28214
# (PV, BESS)          26.79375
# (Wind, BESS)        77.00968
# (PV, Wind, BESS)    77.00968
# Name: (FFR + FCR-D, 2025-04-12 20:00:00), dtype: float64
# Forecasted and Realized rewards:
#                     PV       Wind       BESS   Method Method-Realized
# Forecasted-Value   0.0   25.71829   26.79375  Shapley         Shapley
# Forecasted-Reward  0.0  30.656715  31.732175  Shapley         Shapley
# Realized-Value     0.0   36.28214   26.79375  Shapley         Shapley
# Realized-Reward    0.0  43.249035  33.760645  Shapley         Shapley
# At hour 2025-04-10 14:00:00, optimal partition is [frozenset({'BESS', 'Wind', 'PV'})] with value 6.76275.
# Coalition frozenset({'BESS', 'Wind', 'PV'}) max value at index 0, bid: 6.763, value: 6.763
# Coalition frozenset({'BESS', 'PV', 'Wind'}) max value at index 0, bid: 6.763, value: 6.763
# Forecasted Game Values:
# (PV,)               1.86718
# (Wind,)             0.64810
# (BESS,)             3.75000
# (PV, Wind)          1.76423
# (PV, BESS)          5.84140
# (Wind, BESS)        3.83145
# (PV, Wind, BESS)    6.76275
# Name: (FFR + FCR-D, 2025-04-10 14:00:00), dtype: float64
# Realized Game Values:
# (PV,)                3.32559
# (Wind,)              2.34063
# (BESS,)              3.75000
# (PV, Wind)           4.53003
# (PV, BESS)           7.47493
# (Wind, BESS)         6.98952
# (PV, Wind, BESS)    10.71445
# Name: (FFR + FCR-D, 2025-04-10 14:00:00), dtype: float64
# Forecasted and Realized rewards:
#                          PV      Wind      BESS   Method Method-Realized
# Forecasted-Value    1.86718    0.6481      3.75  Shapley         Shapley
# Forecasted-Reward  2.070373  0.739183  3.953193  Shapley         Shapley
# Realized-Value      3.32559   2.34063      3.75  Shapley         Shapley
# Realized-Reward     3.82489   2.64026    4.2493  Shapley         Shapley

# %% [markdown]
# ## Plot Examples for Convex, Non-Empty Core and Sub-Coaltiions

# %%
v = {}
v[frozenset()] = 0
v[frozenset({'PV'})] = 0.1
v[frozenset({'Wind'})] = 14.9
v[frozenset({'BESS'})] = 0
v[frozenset({'PV', 'Wind'})] = 15
v[frozenset({'PV', 'BESS'})] = 0.1
v[frozenset({'Wind', 'BESS'})] = 22.1
v[frozenset({'PV', 'Wind', 'BESS'})] = 22.2

# %%
# realized game
v = {}
v[frozenset()] = 0
v[frozenset({'PV'})] = 0.1
v[frozenset({'Wind'})] = -44.6
v[frozenset({'BESS'})] = 0
v[frozenset({'PV', 'Wind'})] = -45.1
v[frozenset({'PV', 'BESS'})] = 0.1
v[frozenset({'Wind', 'BESS'})] = -66.3
v[frozenset({'PV', 'Wind', 'BESS'})] = -66.7

# %%
# realized game
v = {}
v[frozenset()] = 0
v[frozenset({'PV'})] = 15.9
v[frozenset({'Wind'})] = 40.2
v[frozenset({'BESS'})] = 0
v[frozenset({'PV', 'Wind'})] = 53.1
v[frozenset({'PV', 'BESS'})] = 30.3
v[frozenset({'Wind', 'BESS'})] = 43.6
v[frozenset({'PV', 'Wind', 'BESS'})] = 58.1

# %%
v[frozenset({'PV'})] + v[frozenset({'Wind'})]
# Out:
# 56.1

# %%
v_new = make_game_superadditive(v, ['PV', 'Wind', 'BESS'])

# %%
v_new
# Out:
# {frozenset(): 0,
#  frozenset({'PV'}): 15.9,
#  frozenset({'Wind'}): 40.2,
#  frozenset({'BESS'}): 0,
#  frozenset({'PV', 'Wind'}): 56.1,
#  frozenset({'BESS', 'PV'}): 30.3,
#  frozenset({'BESS', 'Wind'}): 43.6,
#  frozenset({'BESS', 'PV', 'Wind'}): 70.5}

# %%
is_convex_game(v_new, ['PV', 'Wind', 'BESS'], print_warnings=True)
# Out:
# Game is not convex: frozenset({'BESS', 'PV'}), frozenset({'BESS', 'Wind'})
# False

# %%
get_shapley_value(v, ['PV', 'Wind', 'BESS'])
# Out:
# {'PV': 17.333333333333332,
#  'Wind': 36.13333333333333,
#  'BESS': 4.633333333333333}

# %%
from src.game_theory_helpers import is_convex_game, game_is_superadditive, core_nonempty

# %%
core_nonempty(v, ['PV', 'Wind', 'BESS'])
# Out:
# False
